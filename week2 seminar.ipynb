# %% [markdown]
# -----
# ## Week 02
#
# What to watch to prepare? All are from Moodle
# - Week01 Lecture
#     - https://youtu.be/tIrJ-jCVOt8?si=ByOFZR7PUCSwc9bq
#     - https://youtu.be/fOEK0Epaw10?si=AImRz2xoSlMguIgT
# - Prep and Applied Videos for Quiz-01
#     - https://youtu.be/9-gklNWWWOA?si=WxSfeoBDVbjgqgyi
#     - https://youtu.be/Kd4Fjx00fc4?si=yRqQe2C5QjR8bS76
#     - https://youtu.be/Qhf5TBv1fRU?si=MvJY5KgR7XQvLvV4
# - Other Applied Videos for the class
#     - https://youtu.be/zKfe3llEWEU?si=PoO3NH0z1BTklWDm
#     - https://youtu.be/plARI9CcFhk?si=SXtooMdANXEliv2H
# - Other Useful Videos
#     - https://youtu.be/eTLooKOcjnM?si=fQpP9Tv9RfMfwtNm
#     - https://youtu.be/sduuyIuwTRw?si=vPJBYzsYyhuFjel9
#
# -----
#
# Complexity
# - A recap
#     - what is required to run the algorithm
#     - input is sufficiently large
#         - aka input cannot be empty or small
# - Time
#     - Best, scenario when it is the algorithm is the fastest
#         - binary search = O(1) when the item you are searching for is in the middle
#         - my list is large, n-items
#     - Worst, scenario when it is the algorithm is the slowest
#         - binary search = O(log n) when 1st item (leftmost), last item (rightmost), or not found
#     - Big-O, O(N) upper bound
#         - how it scaling or order of magnitude
#             - linear O(N)
#             - exponential O(2^N)
#         - ignore any constant
#             - O(N) + O(N log N)
#                 - N + N log N = N (1 + log N) = N log N
#             - N * (N - 1) = O(N^2)
#         - only look at the biggest magnitude, order, exponent
#     - Big-Theta, Θ(N) tightest bound
#         - view it as big-O but PRECISE aka tightest bound, due to the lower bound as well
# - Space = input + aux
#     - Input, cant control
#         - bubble sort accepts a list of N items
#             - input space complexity = O(N)
#             - pass by reference, still consider it as the same input space
#     - Auxiliary, extra space
#         - bubble sort accepts a list of N items
#             - O(1) aux space, because it only uses index (pointers), temp var for swapping
#             - O(1) STILL consume space. It means it uses CONSTANT space (aka doesn't scale with input).
#         - INPLACE = O(1) aux
#     - Recursion?
#         - will never be inplace aka wont have O(1) aux space
#         - anything recursion, have to + O(recursive depth)
#         - recursive stack = space used...
#     - Examples:
#         - Is bubble sort inplace? Yes, O(1) aux
#         - Is merge sort inplace? No, resurive stack = O(log N) depth, O(N) aux for temp list merging
# - Time vs Space
#     - time complexity >= aux space complexity
#         - time = O(N), aux space = O(N) is correct
#         - time = O(N^2), aux space = O(1) is correct
#         - time = O(N), aux space = O(N log N) is false
#         - reason: you needd time to create the extra space and fill it up
# - Output sensitive
#     - see lecture
#
# Let's try with binary search
# - Time = ???
# - Space = ???
#     - Input space = ???
#     - Aux space = ???
#
# -----
#
# Recurrence Relation [2-3 marks]
# - What is recursion?
#     - function calling itself
#     - with smaller input
#         - until you reach base case
# - What is recurrence relation?
#     - a relation that describes the time complexity of a recursive algorithm
#     - 2 components
#         - base case, make sure to know how to find it...
#         - recursive case, make sure to know how to find it... and not be fooled. The tricks are here
# - How to solve recurrence relation?
#     1. Telescoping
#         - T(N/k) or T(N-k)
#         - watch the tutorial videos, they are all there
#     2. Master theorem
#         - T(N/k)
#         - can you use T(N-k) with master theorem? NO
# - Logical flow for recurrence relation?
#     1. Pseudocode
#     2. Recurrence relation
#     3. Complexity
#     ... let us now explore step by step, with examples...
#
# -----
#
# Divide and Conquer
# - What is it?
#     - take a large problem
#     - split into smaller problem
#     - solve smallest
#     - combine it together at the end
# - How is it related to Karatsuba?
#     - How it work? A * B
#         1. split A and B into smaller halves
#         2. multiple the smaller halves with each other based on the formula. There is 3 multiplication (4 reduced to 3)?
#         3. Repeat again for each of the halves from step 2 until base case (smol smol numbers)
#     - complexity?
#         - let say A and B has N digits / bits
#         - time = O(N^log_2 3) = O(N^1.59)
#         - space = recursive depth O(log N)
#     - Is it important???
#     - What is important???
# - Application of DnC?
#     - we see in week3 materials and week4 sanity check
