# %% [markdown]
# -----
# ## Week 06
#
# What to watch?
# - We are now in week-6 so more independent effort from you is required.
# - Watch what is stated on Moodle =)
#
# Dijsktra
# - find the shortest path
# (there will not be a better edge, only equivalent)
#     - shortest path from SOURCE
#         - to ALL vertices
#         - to target
#             - terminate earlier
#     - can it work for multiple sources???
#         - No, single source
#         - but you can flip if single destination
#             - what do ian mean???
#     - can it work for multiple destination???
#         - yes
#         - you need to create ???
# - greedy
#     - u = heap.serve()
#         - when u is served, u.distance is already the ??? from source
#     - when u loop through u.edges
#         - you calculate the distance from source to u + edge.w to v
#         - because of the above, we will calculate the shortest distance from source to v going throguh u
#     - that's why it will fail for certain negative edges
#         - more on that later
# - somewhat dynamic programming???
#     - can you explain this?
#     - use memory to save computation
# - vs BFS?
#     - Shortest distance from the source, same as Dijkstra
#         - BFS is the shortest distance by number of edges
#             - weight of all edge is 1
#             - u can use a normal queue
#         - Dijkstra is the shortest distance by weight sum of edges
#             - u need to use a priority queue where closer from source have higher priority (minheap)
# - 2 approach
#     - Large heap (approach 2)
#         - you can use built-in heapq
#         - because your heap have duplicates
#             - why do you have duplicates???
#         1. Size? maximum is O(V^2)
#         2. rise() or sink() complexity is O(log V^2)-> O(log V)
#         3. Number of append()/ serve() is E-times
#         total - O(E log V)
#     - Fixed heap (approach 1 in video)
#         - need to implement own heap
#             - take FIT1008 maxheap, and modify it to minheap
#             - add an update() function, but you need an index-array / mappinng array in O(log V)
#                 - if you go to FIT3155 and learn Fib heap, you can update() in O(1)
#             - tldr go watch my tutorial
#         1. Size? maximum is O(V)
#         2. rise() or sink() complexity is O(log V)
#         3. Number of append()/ serve() is V - times
# - Work for negative edges?
#     - yes, but not 100%
#     - because of this, we don't use dijsktra if there are negative edges
#     - can you work out example on your own?
# - Complexity (for Dijkstra, not the entire graph)
#     - time = O(E log V)
#     - aux space
#         - do you need space for vertices? discovered, visited, distance, previous
#         - do you need space for edges??? nothing
#         - do you need space for heap???? yes max size of heap is =???
# FIRST STEP OF DIJKSTRA  -> reset vertices
#                         ->
# - Some bonus stuffs
#
# Prim's and Kruskal's for Minimum Spanning Tree
# - Graph is UNDIRECTED
# - What is MST?
#     - M = minimum, sum of all edges is Min/ least
#     - S = spanning, all vertices are connected, v-1 edges
#         - can terminate earlier? can, when MST is already have v-1
#     - T = tree
#         - undirected
#         - no cycle
#     - What is the output for this MST?
#         - list of edges that make up the tree
# - Why are they Greedy?
#     - prim's = same dijkstra, vertex v that you serve, edge<v.prev, v> will be part of the MST
#     - kruskal's = edge <u,v> in the sorted list of edges, will be part of the MST is it doesnt form a cycle
# - Prim's = growing of tree
#     - Just like Dijkstra
#     - except 1 modification...
#         - dijkstra = heap look at distance from source (u.distance + e.w)
#         - prim's = heap look at distance from tree (e.w)
# - Kruskal's = merging of trees
#     - sort the edges
#         - sorting algorithm: quicksort -> O(E log E)
#     - Disjoint set
#         - union-find
#             - union-by-size
#             - what it is? plz watch the videos
#         - the parent-array is NOT the MST edges
#             - it is only used to decide if the edge can be added
#             - parent array IS NOT THE OUTPUT
#     - Amortized complexity? Not examinable but let me explain quickly here
# - Work for negative edges?
#     - Prim's: Yes
#     - Kruskal's: Yes
#     what about negative cycles? YES
# - convert to MAXIMUM SPANNING TREE???
#     - prim's = maxheap
#     - kruskal's = sort in youtube
#     - for both = *-i
#     - there are application for maximum spanning tree
