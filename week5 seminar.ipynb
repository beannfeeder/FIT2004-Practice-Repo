# %% [markdown]
# -----
# ## Week05
#
# What to prepare
# - Lecture on Graph, Graph Traversal, Directed Acyclic Graph
#     - https://youtu.be/8S2jKSNC0BQ
#         - PS: We won't cover Dijsktra this week, will save it for next class when Assignment 1 is released.
#     - https://youtu.be/JrN6TrRBQFw
# - Bonus video on BFS and DFS. Please watch it!
#     - https://youtu.be/S6z119kuAfI
# - Applied on Graph and Graph Traversal
#     - https://youtu.be/_EVgZwKLfZg
#
# Graph Data Structure
# - Vertex, O(V)
#     - Node / Entity
#     - What to store? What can be stored?
#         - my vertex is a student
#             - Name
#             - Student ID
#             - Course
#         - my vertex is a location
#             - Coordinates - longitude latitude
#             - Operating hours - can use tuple
#             - status = "open" or self.open = True
#         - anything
# - Edge, O(E)
#     - Relationship connecting vertices
#     - directed or undirected
#         - which to choose? depends on the nature of the relationship
#         - undirected = directed on both side
#             - edge<a,b> is undirected
#                 - edge from a to b
#                 - edge from b to a
#     - weight or unweighted (aka all edges same weight)
#         - what do they represent? value of the relationship
#         - what is the range of values?
#             - can be positive
#             - can be negative
#                 - if a->b is negative, you CANNOT say b->a is positive
#             - can the weight be 0?? YES
#     - What can you store?
#         - distance
#         - likeness
#         - etc
#     - simple graph is our syllabus level, required for many algorithms to work
#         - only single(1) edge from vertex-u to vertex-v
#         - no(0) self-edge
#         - if you need to represent more, you need to design differently
# - Type
#     - Directed vs undirected
#     - Weight vs unweighted
#     - example
#         - directed and weighted: exchange rates
#         - directed and unweighted: train tracks
#         - undirected and weighed: weight
#         - undirected and unweighted: intersection of points
# - Modelling a problem as a graph
#     - What are the vertices?
#     - What are the edges?
#         - Are they directed?
#         - Are they weighted?
#     - Is there possibility for a cycle? there is a path from a vertex back to itself
#         - example of cycle is good: ???
#         - example of cycle is bad: ???
# - Adjacency structure, V vertices and E edges
#     - Adjacency Matrix
#         - need a matrix of size ??? because ??? x ??? vertices
#     - Adjacency List
#         - need an array of size ???, each stores a linked list up to size ???
#             - but total space use is E where E is the total number of edges
#             - E << V^2 if graph is sparse, adjacency list is better
#             - E == V^2 if graph is dense, adjacency matrix is better
#     - When to use which? See the past year exam / practice quiz
#         - Time complexity?
#         - Space complexity?
#         - ... we will visit this time to time...
#     - 1 form of questions, be in your practice quiz
#
# Traversal
# - weight is not important
#     - unless explicitly stated in the tiebreaker
#     - tiebreakers will always be stated in the exam!!!
# - BFS
#     - Concept? go wide
#     - Implementation?
#         - queue, [] append serve
#         - if alphabetical order for tiebreaker, append in alphabetical order
#     - Application?
#         - shortest tree/ distance / height (# edges)
# - DFS
#     - Concept? go deep
#     - Implementation?
#         - stack / recursion, [] push pop
#         - if alphabetical order for tiebreak, push in reverse alphabetical order
#     - Application?
#         - longest tree
#         - pagerank
#         - cycle
# - Complexity?
#     - Time is O(???) if adjacency list. O(???) if adjacency matrix
#         - because you need to go through ???
# - for each other application
#     - go through the tutorial, write down each application
#
# Directed Acyclic Graph (DAG)
# - What is it? Any scenario? What is it for? Application?
#     - topological sort
#     - Application? List them all out!
#         - ???
#         - ???
#         - ???
#     - Make sure to define ur graph
#         - vertex???
#         - edge???
#         - directed???
#         - weighted or unweighted???
# - How can you get it?
#     - Modified DFS
#         1. Take a DFS
#         2. Modify DFS to find topological sort (if it is a DAG).
#             - Push to the output list at the end of function
#     - Kahn's (which is a modified BFS)
#         1. Take BFS
#         2. Modify BFS to find topological sort (if it is a DAG) aka Kahn's.
#             - Vertices are only added, if they no longer have incoming edges
#                 - can maintain a list to keep count, or vertex.incoming attribute
#         - queue is an indicator of unique solution
#             - queue always have item -> topological is unique
#             - queue have >1 item -> branch/ multiple topological sort
# - is topological sort unique???
#     - can you determine if it is unique???
#         - yes, if you have a queue and it is always ??? item in queue, it is unique
#         - no, if you have ??? item in the queue
