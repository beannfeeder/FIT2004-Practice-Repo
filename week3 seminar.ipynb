# %% [markdown]
# -----
# ## Week03
#
# What to watch to prepare? All are from Moodle
# - Week01 Lecture
#     - https://youtu.be/jZOxKx-lqug
#     - https://youtu.be/hUi0SwzJNjg
#     - https://youtu.be/Dk35RzyQHUk
#     - https://youtu.be/hwiNKnB3gAo
# - Prep and Applied Videos for Quiz-02
#     - https://www.youtube.com/watch?v=7X-JSOfQPd4
#     - https://youtu.be/udQcBAJqj-k
#     - And please come to class, I will cover more.
# - Other Applied Videos for the class
#     - https://www.youtube.com/watch?v=5iKwjbsMC3w&t=24s
#     - https://www.youtube.com/watch?v=5iKwjbsMC3w&t=757s
#     - https://www.youtube.com/watch?v=nvsfIQFvHn4
#     - https://youtu.be/vY2p7hVvjM8
# - Other Useful Videos
#     - https://youtu.be/oKIUx13HHy0
#
# -----
#
# Proof of correctness with loop invariants
# - What is invariant?
#     - something that never CHANGES
# - What is loop invariant?
#     - it always TRUE in every iteration
#     - it or combinantion of loop invariants contributes to the correctness/ ensures the output is correct
# - How to prove correctness of an algorithm using loop invariants?
#     - Initialization: ???
#     - Maintenance: ???
#     - Termination: ???
#
#     INCLUDE WHAT HAPPENS INSIDE THE LOOP
#     - Let's use a past year example.
# Exclude what is in the iteration itself
# ----
#
# Recap of sorting
# - Time complexity
#     - number of comparisons
#     - number of swaps
#     - number of comparisons >= number of swaps
# - Space complexity
#     - assume u sort list[1...N]
#         - why 1...N and not 0...N-1?
#         -
#     - input space: O(N)
#     - aux space:
#         - O(1) aka constant space aka inplace. What are the sorting algorithms?
#         - O(log N) = Binary Sort
#         - O(N) = Selection, Insertion
# - Stability
#     - maintain relative order / relative order doesnt change
#     - shifting is usually stable. Why???
#         - example = mergesort (left before right sublist)
#     - swapping (not next to each other) is usually unstable unless the swap maintain order (aka mergesort, left before right sublist). Why???
#         - example = quicksort
# - The items matter for comparison-based sorts (bubble, selection, insertion, heap, merge, quick)
#     - String with M chars, O(M)
#         example: bubble sort will be O(N^2)
#     - Integer with B-base, O(1)
#         - why? hardware MAGIC
# - Let's use a pass year example...
#     - LO3 compare and contrast questions are popular!
#     - Let us build a table, comparing all sorts
#         - Best case
#         - Worst case
#         - What happen when best case == worst case?
#         - Aux space
# - Application of sorting? watch the tutorial
#     - it groups similar items together
#     - what else???
#
# -----
#
# Counting Sort
# - Not comparison-based
#     - no comparison, no swapping
#     - therefore no comparison cost!!!
# - Concept
#     - count the freq, rebuild back based on frequency
# - Concept with the bucket variant (recommended or what you should be doing)
#     - append into bucket (aka a bucket for small, medium, big fish)
#     - can implement a normal queue (linked) or just assume Python's [] list is ok
# - Time complexity, for N items, with M largest item (integer)
#     1. find max O(N)
#     2. initialize count_array O(r)
#     3. loop through list, update count_array O(n)
#     4. loop through count_array, rebuild original list O(r+n)
#     - Total = ???
# - consider the following
#     - I have N items, let say = 100
#     - Biggest item is 1,000,000
#     - N = 100, M = 1,000,000, M = N^3
#     - what is the complexity??? O(???)
#     - should you use counting sort for this scenario???
# - Space complexity
#     - input list = O(???)
#     - count_array = O(???)
#     - count_array if unstable = O(???), aux_space = O(???)
#     - count array if stable = O(???), aux_space = O(???)
#     - total space = input + aux = O(???)
# - What happen if your list smallest item is negative?
#     - list, min=-322, max=420
#     - what can you do???
#     - M can be the range, not the max!!!
#
# -----
#
# Radix sort
# - Not comparison-based
# - Concept
#     - counting sort but with columns
#         - number of columns k = log_base (max_item) + 1 = ???
#         - choosing a suitable base (up to N) will ensure linear complexity
#             - base shouldnt be >= N or anything, cause it affect count_array thus wont be ???
#             - can you try with different value of M?
#             - in order words, we abuse the log function to split M into multiple chunks of N. This result in us having k columns.
#             - recall counting sort is O(N + b), radix sort is O(kN + kb) where b is the base. Thus you can see how we manipulat M -> kb
#         - if M is a function of N, that is less than N^N or N!, choosing a base of N will ensure linear complexity
#             - let's try this...
#         - common mistake from what i see in the code review of earlier semesters
#             - counting sort we have to find the max() for count-array.
#                 - Do we need it for radix sort? ???
#             - how do you calculate the number of columns?
#                 - What is the formula???
#             - what about the formula to determine value for each column?
#                 - What is the formula???
#     - count_array or bucket_array
#         - depends on ur base
#     - number of columns
#         - relationship vs base?
#         - see equation above
# - Complexity?
#     - N = number of items
#     - M = largest item
#     - k = number of columns
#     - b = base
#     - Time complexity? O(???)
#     - Aux Space? O(???)
# - Optimization for string?
#     - Using length, if the length differs
#     - Depends if left-align or right-align for string
#     - Also see if u loop bottom-up or top-down, do explore this and i wont give you the answer.
#     - There is an extra video I recorded about this.
# - When to use radix sort vs other sort?
#     - Give me a list...
#     - we do this next week when we compare sorts... but till then, use the table!!!
# - Now let us extend the table we drew earlier...
